# %% [markdown]
# ## Decorators
#
# 1. Functions are objects
#
# - functions are actually objects.
# - and that basically means that a function is very similar to something like a string or a number or a list.
# - basically a function can be used in the same way that these other data types can also be used
#
#
# - in Python we always use these open and closed parentheses and you might be wondering what exactly these do essentially when you put an open and close parenthesis after a function it indicates that we want to call the function so we want to execute all of the code inside potentially with some in arguments
#
#
# 2. functions within functions
#
# -
#
# 3. returning functions from functions
#
# -
#
# 4. decorating a function
#
#
# decorator function all it does is return
# a new function which executes that
# existing function that got passed in
# along with some additional functionality
# so we would call this decorating a
# function because we're decorating the
# print name function with some additional
# prints or whatever I mean it could be
# any possible thing that you could put in
# code
#
#
# 5. decorators
#
# here in this fifth section I want to
# talk to you about Python decorators so
# we saw how we can create a decorator
# function but there's a way of doing this
# in Python which is actually really easy
# so the the complicated syntax is down
# here right this is kind of annoying
# where we have to wrap this function over
# here we have to pass it into the
# decorator it's it's this very like
# tedious and manual process right to
# doing all of this I can actually get rid
# of all of this and up here I can just
# make an @ sign and then I can type in
# the name of the decorator so I can type
# in title decorator and now check this
# out if I just go print my name if I
# execute print my name it's actually
# going to decorate it automatically so
# you'll see here we're printing out
# professor Mike so it'll do all of this
# code for us right all of this is going
# to be done in the background like python
# will take care of that
# and we can just call the function
# normally so you put this decorator
# annotation right above the function so
# it has to go directly above here and
# then we're able to use that so I can do
# the same thing for print Joe's name so
# right now if I did print Joe's name and
# I tried to execute this you see it just
# says Joe but if I wanted I can decorate
# it with the title decorator and now when
# I print this out you'll see we get that
# title so that's how decorators work and
# the main concept that you really need to
# understand here is this idea of a
# wrapper function that gets both defined
# and returned from the decorator function
# this wrapper function is very important
# because it's this wrapper function which
# allows us to package up additional
# functionality with the functionality
# that's given to us in the form of our
# print name function and so these
# decorators can have a lot of different
# uses and as you learn more about Python
# you'll discover more and more useful
# decorators and so a lot of times a
# decorator like this would be defined in
# a separate file it might even be defined
# in some sort of a library file that you
# might have to download with pip or
# something and the whole point of is it
# kind of gets abstracted away so all you
# have to worry about is just doing this
# decorator annotation and then it sort of
# works for you
#
# 6. decorators w/ parameters
#
# to kind
# of clean this up a bit let's say that
# the print name function I wanted this to
# be able to take in a name so the print
# my name it should be able to take in a
# name and then down here we'll just print
# the name so we can kind of customize
# what the name is so in here I could pass
# in like Shelby and now if I run this and
# notice that I got rid of the decorator I
# commented it out now when I run this
# you'll see that we just print out Shelby
# so I can pass in whatever name I want to
# pass in but if I put this decorator back
# in we're actually gonna get an error and
# you'll see what happens in a
# again see we're getting a type error so
# rapper this function over here doesn't
# take any positional arguments but we
# gave it the name so if I want to be able
# to accept arguments here in my function
# that's getting decorated.
#
# <br>I have to get a
# little bit fancier with my syntax so
# over here all we have to do here inside
# of the wrapper is we're just going to
# put args and then we're gonna put KW
# args and so we can put that right there
# and then we're also going to pass that
# in here when we execute our print named
# function so all you have to do is just.
# what that'll do is it'll pass in any
# of the parameters I need the arguments
# that were passed into the print name
# function into the wrapper function and
# then the wrapper function will then pass
# them into the print name function so the
# the parameters the arguments basically
# just get piped through this function
# structure and we'll be able to use that
# so now if I was to run my program and
# whoops you have to put two stars here
# two asterisks.<br>
# and you'll see that it gets decorated
# just fine and you could put other
# parameters in here too so for example if
# I put in like an age I could say we
# could print out their age and then over
# here we if we pass in an age
# you'll see that it does that just fine
# so basically you can have you know as
# many arguments as you want and they'll
# get passed through this structure so
# that's gonna do it for my explanation on
# decorators and Python and really when it
# comes down to it decorators are just
# fancy ways of working with functions so
# as you saw in our decorating a function
# section section four we don't need this
# fancy you know @ symbol syntax we don't
# need that syntax in order to use
# decorators but it does make it a lot
# easier and a lot simpler because we
# don't have as much complex syntax so
# this is kind of what we would call
# syntactic sugar

# %%
# 1. Functions are objects

def add_five(num):
    print(num + 5)
    
add_five(2)

# 2. functions within functions

def add_five(num):
    def add_two(num):
        return num + 2
    num_plus_two = add_two(num)
    print(num_plus_two + 3)

add_five(10)

# 3. returning functions from functions

def get_math_function(operation): # + or -
    def add(n1, n2):
        return n1 + n2
    def sub(n1, n2):
        return n1 - n2
    if operation == '+':
        return add
    elif operation == '-':
        return sub
add_function = get_math_function('+')
sub_function = get_math_function('-')
print ( add_function(4, 6) )
print ( sub_function(4, 6) )

# 4. decorating a function

def title_decorator(print_name_function):
    def wrapper():
        print("Professor:")
        print_name_function()
    return wrapper
        
        
def print_my_name():
    print("Albert")
    
def print_joes_name():
    print("Joe")
    
decorated_function = title_decorator(print_joes_name)

decorated_function()

# 5. decorators

def title_decorator(print_name_function):
    def wrapper():
        print("Professor:")
        print_name_function()
    return wrapper
        
@title_decorator        
def print_my_name():
    print("Albert")
    
@title_decorator
def print_joes_name():
    print("Joe")
    
print_my_name()

# 6. decorators w/ parameters

def title_decorator(print_name_function):
    def wrapper(*args, **kwargs):
        print("Professor:")
        print_name_function(*args, **kwargs)
    return wrapper
        
@title_decorator        
def print_my_name(name, age):
    print(name + " you are " + str(age))
    

print_my_name("Shelby", 50)
# Out:
# 7
# 15
# 10
# -2
# Professor:
# Joe
# Professor:
# Albert
# Professor:
# Shelby you are 50
